# %% [markdown]
# #Experiment No 01: Introduction to NLP String Processing
# <br> Rebecca Dias
# <br> Roll no: 18 BE CMPN A2
# <br>Pid: 182027
# <br><br>Aim: To perform the various processing techniques on string in Python

# %% [markdown]
# ## String Entries

# %%
string = input("Enter the string 1: ")
# Out:
# Enter the string 1: rebecca dias

# %%
string2 = input("Enter the string 2: ")
# Out:
# Enter the string 2: sarah

# %%
string3, n = input("Enter the string and the nth index separated by a space: ").split(" ")
# Out:
# Enter the string and the nth index separated by a space: rebecca 7

# %%
word, tag = input("Enter the word and tag space separated: ").split(" ")
# Out:
# Enter the word and tag space separated: nathan h1

# %% [markdown]
# ## Usage of Built-in Functions in String

# %%
import string

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.hexdigits
# Out:
# '0123456789abcdefABCDEF'

# %%
string.digits
# Out:
# '0123456789'

# %%
str = "Rebecca"

# %%
string.octdigits
# Out:
# '01234567'

# %%
print(str.endswith("a"))
# Out:
# True

# %%
print(str.startswith("f"))
# Out:
# False

# %%
str.isdigit()
# Out:
# False

# %%
a = "\u0030" #unicode for 0
b = "\u0047" #unicode for G

print(a.isdecimal())
print(b.isdecimal())
# Out:
# True
# False

# %%
txt = "I am {age: d} years old!"
print(txt.format(age=21))
# Out:
# I am  21 years old!

# %%
txt = "Hello World"
print(txt.index("World"))
# Out:
# 6

# %%
print(str.upper())
# Out:
# REBECCA

# %%
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
print("Hello")
# Storing the characters space, tab etc
result = string.whitespace
  
# Printing the values
print(result)
print("World")
# Out:
# Hello
#
#
# World

# %%
print(txt.swapcase())
# Out:
# hELLO wORLD

# %%
print(txt.replace("World","Rebs"))
# Out:
# Hello Rebs

# %%
a = "HELLO, AND WELCOME TO MY WORLD"
b = "Hello"
c = "22 Names"
d = "This Is %'!?"

print(a.istitle())
print(b.istitle())
print(c.istitle())
print(d.istitle())
# Out:
# False
# True
# True
# True

# %%
txt.partition("World")
# Out:
# ('Hello ', 'World', '')

# %%
a = "MyFolder"
b = "Demo002"
c = "2bring"
d = "my demo"

print(a.isidentifier())
print(b.isidentifier())
print(c.isidentifier())
print(d.isidentifier())
# Out:
# True
# True
# False
# False

# %%
len(str)
# Out:
# 7

# %%
txt.rindex("World")
# Out:
# 6

# %%
max(str)
# Out:
# 'e'

# %%
String = "Be grateful\nBe happy"
x = String.splitlines()
print(x)
# Out:
# ['Be grateful', 'Be happy']

# %%
string = "Rebecca Hilary Dias"
print(string.capitalize())

name1 = "rebecca"
name2 = "hilary"
name3 = "dias"
print(name1.capitalize() + name2.capitalize()
                         + name3.capitalize())
# Out:
# Rebecca hilary dias
# RebeccaHilaryDias

# %%
string = "H\te\tl\tl\to"
x =  string.expandtabs(2)
print(x)
# Out:
# H e l l o

# %%
string = 'This is NLP subject'
print(string.find('NLP'))
# Out:
# 8

# %%
result = string.rfind('NLP subject')
print("Substring 'NLP subject':", result)
# Out:
# Substring 'NLP subject': 8

# %%
string.count("i")
# Out:
# 2

# %%
string.lower()
# Out:
# 'this is nlp subject'

# %%
string.split()
# Out:
# ['This', 'is', 'NLP', 'subject']

# %%
string.rsplit(" ")
# Out:
# ['This', 'is', 'NLP', 'subject']

# %%
txt = "cleanliness is next to godliness"
x = txt.rpartition("next")
print(x)
# Out:
# ('cleanliness is ', 'next', ' to godliness')

# %%
' '.join(txt)
# Out:
# 'c l e a n l i n e s s   i s   n e x t   t o   g o d l i n e s s'

# %%
("            blah         ").strip()
# Out:
# 'blah'

# %%
("            blah         ").lstrip()
# Out:
# 'blah         '

# %%
("            blah         ").rstrip()
# Out:
# '            blah'

# %%
#use a dictionary with ascii codes to replace 83 (S) with 80 (P):
mydict = {83:  80}
txt = "Hello Sam!"
print(txt.translate(mydict))
# Out:
# Hello Pam!

# %%
string.ljust(10)
# Out:
# 'This is NLP subject'

# %%
string.center(20)
# Out:
# 'This is NLP subject '

# %%
txt.zfill(20)
# Out:
# '0000000000Hello Sam!'

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# 1. Write a Python program to calculate the length of a string.

# %%
def calc_len(string):
  return len(string)


print(calc_len(string))
# Out:
# 19

# %% [markdown]
# 2. Write a Python program to count the number of characters in a string.

# %%
def count_char(string):
  return len(string.replace(" ",""))

print(count_char(string))
# Out:
# 16

# %% [markdown]
# 3. Write a Python program to get a string made of the first 2 and the last 2 chars
# from a given a string. If the string length is less than 2, return instead of the
# empty string.

# %%
def join_f_l_2(string):
  if len(string) < 2:
    return
  else:
    return (string[:2]+string[-2:])

print(join_f_l_2(string))
# Out:
# Thct

# %% [markdown]
# 4. Write a Python program to get a string from a given string where all
# occurrences of its first char have been changed to &#39;$&#39;, except the first char itself.

# %%
def replace_fchar_with_dollar(inputs):
  string1 = string.replace(inputs[0], '$')  
  return (inputs[0] + inputs[1:]) 

inputs = input("Enter the string to count characters >>>> ")
print(replace_fchar_with_dollar(inputs))
# Out:
# Enter the string to count characters >>>> rebecca dias
# rebecca dias

# %% [markdown]
# 5. Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.

# %%
def swap_first_two(string1,string2):
  str1 = string2[:2] + string1[2:]
  str2 = string1[:2] + string2[2:] 
  return (str1+" "+str2) 

string1, string2 = input("Enter the two string separated by space for swap >>>> ").split(" ")
print(swap_first_two(string1, string2))
# Out:
# Enter the two string separated by space for swap >>>> reb dias
# dib reas

# %% [markdown]
# 6. Write a Python program to add &#39;ing&#39; at the end of a given string (length should
# be at least 3). If the given string already ends with 'ing' then add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.

# %%
def add_ing(string):
  if len(string) > 2:
    if string[-3:] == 'ing':
      string += 'ly'
    else:
      string += 'ing'
  return string

string = input("Enter the string >>>> ")
print(add_ing(string))
# Out:
# Enter the string >>>> rebly
# reblying

# %% [markdown]
# 7. Write a Python program to find the first appearance of the substring &#39;not&#39; and
# &#39;poor&#39; from a given string, if &#39;not&#39; follows the &#39;poor&#39;, replace the whole
# &#39;not&#39;...&#39;poor&#39; substring with &#39;good&#39;. Return the resulting string.

# %%
def not_poor_edit(string):
  nott = string.find('not')
  poor = string.find('poor')
  if (poor > nott and nott > 0 and poor > 0):
    string = string.replace(string[nott:(poor+4)], 'good')
    return string
  else:
    return string
string = input("Enter the string >>>> ")
print(not_poor_edit(string))
# Out:
# Enter the string >>>> i am not poor
# i am good

# %% [markdown]
# 8. Write a Python function that takes a list of words and returns the length of the
# longest one.

# %%
def find_longest(str_list):
  str_list_l = []
  for i in str_list:
    str_list_l.append((len(i), i))
  str_list_l.sort()
  
  return (str_list_l[-1][0], str_list_l[-1][1])

str_list = list(input("Enter the words space separated >>>> ").split(" "))
print(find_longest(str_list))
# Out:
# Enter the words space separated >>>> rebecca dias
# (7, 'rebecca')

# %% [markdown]
# 9. Write a Python program to remove the nth index character from a nonempty
# string.

# %%
def remove_n(string, n):  
  f = string[:n]   
  l = string[n+1:]  
  return f + l
string, n = input("Enter the string and the nth index separated by a space >>>> ").split(" ")
print(remove_n(string, int(n)))
# Out:
# Enter the string and the nth index separated by a space >>>> rebecca 3
# rebcca

# %% [markdown]
# 10. Write a Python program to change a given string to a new string where the first
# and last chars have been exchanged.

# %%
def replace_f_l(string):  
  return string[-1:] + string[1:-1] + string[:1]
string = input("Enter the string >>>> ")
print(replace_f_l(string))
# Out:
# Enter the string >>>> rebecca dias
# sebecca diar

# %% [markdown]
# 11. Write a Python program to remove the characters which have odd index values
# of a given string.

# %%
def remove_odd_index(string):  
  return (string[::2])
string = input("Enter the string >>>> ")
print(remove_odd_index(string))
# Out:
# Enter the string >>>> sachin
# sci

# %% [markdown]
# 12. Write a Python program to count the occurrences of each word in a given
# sentence.

# %%
def count_occr(string):
  word_c = {}
  words = string.split()
  for i in words:
    if i in word_c:
      word_c[i] += 1
    else:
      word_c[i] = 1
  return word_c
string = input("Enter the string >>>> ")
print(count_occr(string))
# Out:
# Enter the string >>>> i am a i am good boy
# {'i': 2, 'am': 2, 'a': 1, 'good': 1, 'boy': 1}

# %% [markdown]
# 13. Write a Python script that takes input from the user and displays that input back
# in upper and lower cases.

# %%
def get_up_low(string):
  return(string.upper()+" "+string.lower())
string = input("Enter the string >>>> ")
print(get_up_low(string))
# Out:
# Enter the string >>>> hey
# HEY hey

# %% [markdown]
# 14. Write a Python program that accepts a comma separated sequence of words as
# input and prints the unique words in sorted form (alphanumerically).

# %%
def get_unique(string):
  words = [word for word in string.split(",")]
  return (",".join(sorted(list(set(words)))))
string = input("Enter the string >>>> ")
print(get_unique(string))
# Out:
# Enter the string >>>> hello,world,i,am,reb
# am,hello,i,reb,world

# %% [markdown]
# 15.Write a Python function to create the HTML string with tags around the
# word(s).

# %%
def html_tag(tag, word):
	return (f"<{tag}> {word} </{tag}>")
word, tag = input("Enter the word and tag space separated >>>> ").split(" ")
print(html_tag(tag, word))
# Out:
# Enter the word and tag space separated >>>> hello h2
# <h2> hello </h2>

# %% [markdown]
# #Conclusion: <br>
# Implemented various string processing techniques on strings in Python.We used the Built-in Functions in string and performed various programming exercises.
